# %%
# Import our dependencies
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# Read in Movies CSV
movies_df = pd.read_csv("Resources/movies.csv")
movies_df
# Out:
#                                           movie_name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life    NaN      Drama
# 7664                                     Dream Round    NaN     Comedy
# 7665                                   Saving Mbango    NaN      Drama
# 7666                                    It's Just Us    NaN      Drama
# 7667                                       Tee em el    NaN     Horror
#
#       year_release  score      votes         director  \
# 0             1980    8.4   927000.0  Stanley Kubrick
# ...

# %%
# Check for duplicates in the dataset movies_df
print(f"Duplicate entries: {movies_df['movie_name'].duplicated().sum()}")
# Out:
# Duplicate entries: 156

# %%
# Drop duplicates from movies_df
movies_df.drop_duplicates(subset="movie_name", keep=False, inplace=True)
movies_df
# Out:
#                                           movie_name rating      genre  \
# 0                                        The Shining      R      Drama
# 1                                    The Blue Lagoon      R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                          Airplane!     PG     Comedy
# 4                                         Caddyshack      R     Comedy
# ...                                              ...    ...        ...
# 7663                                    More to Life    NaN      Drama
# 7664                                     Dream Round    NaN     Comedy
# 7665                                   Saving Mbango    NaN      Drama
# 7666                                    It's Just Us    NaN      Drama
# 7667                                       Tee em el    NaN     Horror
#
#       year_release  score      votes         director  \
# 0             1980    8.4   927000.0  Stanley Kubrick
# ...

# %%
# drop rows with Na values in movies_df
movies_df = movies_df.dropna()
movies_df
# Out:
#                                           movie_name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year_release  score      votes         director  \
# ...

# %%
#reset the index so that it is in order
movies_df = movies_df.reset_index(drop=True)
movies_df.count()
# Out:
# movie_name      5201
# rating          5201
# genre           5201
# year_release    5201
# score           5201
# votes           5201
# director        5201
# writer          5201
# star            5201
# country         5201
# budget          5201
# gross           5201
# company         5201
# runtime         5201
# dtype: int64

# %%
# Read in Top Movies CSV
top_4000_movies_df = pd.read_csv("Resources/top_4000_movies_data.csv", parse_dates=['Release Date'], dayfirst=True)
top_4000_movies_df
# Out:
#      Release Date                                  Movie Title  \
# 0      2019-04-23                            Avengers: Endgame
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2015-04-22                      Avengers: Age of Ultron
# 3      2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4      2018-04-25                       Avengers: Infinity War
# ...           ...                                          ...
# 3995   2067-06-13                          You Only Live Twice
# 3996   1988-10-06                              Poltergeist III
# 3997   2016-12-21                                       Dangal
# 3998   2010-03-19                                 The Runaways
# 3999   2009-10-30                            Gentlemen Broncos
#
#       Production Budget  Domestic Gross  Worldwide Gross
# 0             400000000       858373000       2797800564
# 1             379000000       241071802       1045713802
# ...

# %%
# Check for duplicates in the dataset top_4000_movies_df
print(f"Duplicate entries: {top_4000_movies_df['Movie Title'].duplicated().sum()}")
# Out:
# Duplicate entries: 48

# %%
# Drop duplicates from movies_df
top_4000_movies_df.drop_duplicates(subset="Movie Title", keep=False, inplace=True)

# %%
# count number of rows
top_4000_movies_df.count()
# Out:
# Release Date         3883
# Movie Title          3904
# Production Budget    3904
# Domestic Gross       3904
# Worldwide Gross      3904
# dtype: int64

# %%
# Check for duplicates in the dataset top_4000_movies_df
print(f"Duplicate entries: {top_4000_movies_df['Movie Title'].duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# drop rows with Na values
top_4000_movies_df = top_4000_movies_df.dropna()

# %%
# rename columns for 
top_4000_movies_df.rename(columns={'Release Date':'Release_Date', 'Movie Title':'Movie_Title', 'Production Budget':'Production_Budget', 'Domestic Gross':'Domestic_Gross',
       'Worldwide Gross':'Worldwide_Gross'},inplace=True)
# Out:
# C:\Users\dtj13\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# reset the index so that it is in order
top_4000_movies_df.reset_index(drop=True)
# Out:
#      Release_Date                                  Movie_Title  \
# 0      2019-04-23                            Avengers: Endgame
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2015-04-22                      Avengers: Age of Ultron
# 3      2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4      2018-04-25                       Avengers: Infinity War
# ...           ...                                          ...
# 3878   2067-06-13                          You Only Live Twice
# 3879   1988-10-06                              Poltergeist III
# 3880   2016-12-21                                       Dangal
# 3881   2010-03-19                                 The Runaways
# 3882   2009-10-30                            Gentlemen Broncos
#
#       Production_Budget  Domestic_Gross  Worldwide_Gross
# 0             400000000       858373000       2797800564
# 1             379000000       241071802       1045713802
# ...

# %%
# count the number of rows
top_4000_movies_df.count()
# Out:
# Release_Date         3883
# Movie_Title          3883
# Production_Budget    3883
# Domestic_Gross       3883
# Worldwide_Gross      3883
# dtype: int64

# %%
# create string to access postgreSQL database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_final"

# %%
# create engine for sqalchemy
engine = create_engine(db_string)

# %%
# export movies_df to movies table
movies_df.to_sql(name='movies', con=engine, index=False)

# %%
# export top_4000_movies_df
top_4000_movies_df.to_sql(name='top_4000_movies', con=engine, index=False)

# %%
# read in merged_movie_df from pgAdmin and postgreSQL
merged_movies_df = pd.read_sql_query('''SELECT * FROM merged_movies;''', engine)
merged_movies_df
# Out:
#                             movie_name rating   genre  year_release  score  \
# 0                    Avengers: Endgame  PG-13  Action          2019    8.4
# 1              Avengers: Age of Ultron  PG-13  Action          2015    7.3
# 2               Avengers: Infinity War  PG-13  Action          2018    8.4
# 3                       Justice League  PG-13  Action          2017    6.1
# 4                              Spectre  PG-13  Action          2015    6.8
# ...                                ...    ...     ...           ...    ...
# 5196                     The Grey Zone      R   Drama          2001    7.0
# 5197                   Boyz n the Hood      R   Crime          1991    7.8
# 5198  Once Upon a Time... In Hollywood      R  Comedy          2019    7.6
# 5199                     House Party 2      R  Comedy          1991    5.3
# 5200                       Naked Lunch      R   Drama          1991    7.0
#
# ...

# %%
# drop the Release_Date and country columns
merged_movies_df = merged_movies_df.drop(['Release_Date', 'country'], axis=1)
merged_movies_df.head()
# Out:
#                 movie_name rating   genre  year_release  score     votes  \
# 0        Avengers: Endgame  PG-13  Action          2019    8.4  903000.0
# 1  Avengers: Age of Ultron  PG-13  Action          2015    7.3  777000.0
# 2   Avengers: Infinity War  PG-13  Action          2018    8.4  897000.0
# 3           Justice League  PG-13  Action          2017    6.1  418000.0
# 4                  Spectre  PG-13  Action          2015    6.8  393000.0
#
#         director              writer               star       budget  \
# 0  Anthony Russo  Christopher Markus  Robert Downey Jr.  356000000.0
# 1    Joss Whedon         Joss Whedon  Robert Downey Jr.  250000000.0
# 2  Anthony Russo  Christopher Markus  Robert Downey Jr.  321000000.0
# 3    Zack Snyder        Jerry Siegel        Ben Affleck  300000000.0
# 4     Sam Mendes          John Logan       Daniel Craig  245000000.0
#
#           gross         company  runtime  Production_Budget  Domestic_Gross  \
# ...

# %%
# drop duplicate title names
merged_movies_df = merged_movies_df.drop_duplicates(subset= 'movie_name', keep= 'first', inplace=False)
merged_movies_df
# Out:
#                             movie_name rating   genre  year_release  score  \
# 0                    Avengers: Endgame  PG-13  Action          2019    8.4
# 1              Avengers: Age of Ultron  PG-13  Action          2015    7.3
# 2               Avengers: Infinity War  PG-13  Action          2018    8.4
# 3                       Justice League  PG-13  Action          2017    6.1
# 4                              Spectre  PG-13  Action          2015    6.8
# ...                                ...    ...     ...           ...    ...
# 5196                     The Grey Zone      R   Drama          2001    7.0
# 5197                   Boyz n the Hood      R   Crime          1991    7.8
# 5198  Once Upon a Time... In Hollywood      R  Comedy          2019    7.6
# 5199                     House Party 2      R  Comedy          1991    5.3
# 5200                       Naked Lunch      R   Drama          1991    7.0
#
# ...

# %%
# drop rows with na values
merged_movies_df = merged_movies_df.dropna()
merged_movies_df
# Out:
#                    movie_name rating      genre  year_release  score  \
# 0           Avengers: Endgame  PG-13     Action          2019    8.4
# 1     Avengers: Age of Ultron  PG-13     Action          2015    7.3
# 2      Avengers: Infinity War  PG-13     Action          2018    8.4
# 3              Justice League  PG-13     Action          2017    6.1
# 4                     Spectre  PG-13     Action          2015    6.8
# ...                       ...    ...        ...           ...    ...
# 2720            The Lost City      R      Drama          2005    6.6
# 2721              Next Friday      R     Comedy          2000    6.2
# 2722          Poltergeist III     PG     Horror          1988    4.7
# 2723             The Runaways      R  Biography          2010    6.5
# 2724        Gentlemen Broncos  PG-13  Adventure          2009    6.2
#
#          votes           director                     writer  \
# 0     903000.0      Anthony Russo         Christopher Markus
# ...
