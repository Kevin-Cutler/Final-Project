# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevin-Cutler/Final-Project/blob/Kevin_Test_Branch/Class_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# Initial imports.
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Read in Movies CSV
movies_df = pd.read_csv("/content/movies.csv")
movies_df.head(20)
# Out:
#                                               name  ... runtime
# 0                                      The Shining  ...   146.0
# 1                                  The Blue Lagoon  ...   104.0
# 2   Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                        Airplane!  ...    88.0
# 4                                       Caddyshack  ...    98.0
# 5                                  Friday the 13th  ...    95.0
# 6                               The Blues Brothers  ...   133.0
# 7                                      Raging Bull  ...   129.0
# 8                                      Superman II  ...   127.0
# 9                                  The Long Riders  ...   100.0
# 10                           Any Which Way You Can  ...   116.0
# 11                          The Gods Must Be Crazy  ...   109.0
# 12                                          Popeye  ...   114.0
# 13                                 Ordinary People  ...   124.0
# 14                                 Dressed to Kill  ...   104.0
# 15                               Somewhere in Time  ...   103.0
# 16                                            Fame  ...   134.0
# 17                                          9 to 5  ...   109.0
# 18                                         The Fog  ...    89.0
# 19                                      Stir Crazy  ...   111.0
#
# [20 rows x 15 columns]

# %%
# Check for duplicates in the dataset movies_df
print(f"Duplicate entries: {movies_df['name'].duplicated().sum()}")
# Out:
# Duplicate entries: 156

# %%
# Read in Top Movies CSV
top_4000_movies_df = pd.read_csv("/content/top_4000_movies_data.csv", parse_dates=['Release Date'], dayfirst=True)
top_4000_movies_df.head(20)
# Out:
#    Release Date  ... Worldwide Gross
# 0    2019-04-23  ...      2797800564
# 1    2011-05-20  ...      1045713802
# 2    2015-04-22  ...      1395316979
# 3    2015-12-16  ...      2064615817
# 4    2018-04-25  ...      2044540523
# 5    2007-05-24  ...       960996492
# 6    2017-11-13  ...       655945209
# 7    2015-06-10  ...       879500760
# 8    2019-12-18  ...      1072848487
# 9    2018-05-23  ...       393151347
# 10   2012-07-03  ...       282778100
# 11   2016-03-23  ...       872395091
# 12   2017-12-13  ...      1331635141
# 13   2019-11-07  ...      1654367425
# 14   2010-11-24  ...       584899819
# 15   2007-04-05  ...       894860230
# 16   2016-04-22  ...      1151918521
# 17   2009-07-15  ...       929411069
# 18   2013-12-12  ...       959358436
# 19   2014-10-12  ...       940389558
#
# [20 rows x 5 columns]

# %%
# Check for duplicates in the dataset top_4000_movies_df
print(f"Duplicate entries: {top_4000_movies_df['Movie Title'].duplicated().sum()}")
# Out:
# Duplicate entries: 48

# %%
top_4000_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release Date       3979 non-null   datetime64[ns]
#  1   Movie Title        4000 non-null   object
#  2   Production Budget  4000 non-null   int64
#  3   Domestic Gross     4000 non-null   int64
#  4   Worldwide Gross    4000 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 156.4+ KB

# %%
top_4000_movies_df.nunique()
# Out:
# Release Date         2267
# Movie Title          3952
# Production Budget     280
# Domestic Gross       3828
# Worldwide Gross      3939
# dtype: int64

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
movies_df.nunique()
# Out:
# name        7512
# rating        12
# genre         19
# year          41
# released    3414
# score         72
# votes        936
# director    2949
# writer      4535
# star        2814
# country       59
# budget       413
# gross       7472
# company     2385
# runtime      138
# dtype: int64

# %%
# See what data you have available
movies_df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
# See what data you have available
top_4000_movies_df.columns
# Out:
# Index(['Release Date', 'Movie Title', 'Production Budget', 'Domestic Gross',
#        'Worldwide Gross'],
#       dtype='object')

# %%
# Combine the data into a single dataset.
#Merged_Movie_df = top_4000_movies_df.merge( movies_df, left_on='Movie Title', right_on='name')
Merged_Movie_df = top_4000_movies_df.merge( movies_df, how='inner', left_on='Movie Title', right_on='name')

Merged_Movie_df.head(100)
# Out:
#    Release Date              Movie Title  ...               company  runtime
# 0    2019-04-23        Avengers: Endgame  ...        Marvel Studios    181.0
# 1    2015-04-22  Avengers: Age of Ultron  ...        Marvel Studios    141.0
# 2    2018-04-25   Avengers: Infinity War  ...        Marvel Studios    149.0
# 3    2017-11-13           Justice League  ...          Warner Bros.    120.0
# 4    2015-06-10                  Spectre  ...                   B24    148.0
# ..          ...                      ...  ...                   ...      ...
# 95   2019-05-22                  Aladdin  ...  Walt Disney Pictures    128.0
# 96   1992-11-11                  Aladdin  ...  Walt Disney Pictures     90.0
# 97   1992-11-11                  Aladdin  ...  Walt Disney Pictures    128.0
# 98   2017-10-25           Thor: Ragnarok  ...  Walt Disney Pictures    130.0
# 99   2014-05-28               Maleficent  ...             Jolie Pas     97.0
#
# [100 rows x 20 columns]

# %%
Merged_Movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3121 entries, 0 to 3120
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release Date       3121 non-null   datetime64[ns]
#  1   Movie Title        3121 non-null   object
#  2   Production Budget  3121 non-null   int64
#  3   Domestic Gross     3121 non-null   int64
#  4   Worldwide Gross    3121 non-null   int64
#  5   name               3121 non-null   object
#  6   rating             3117 non-null   object
#  7   genre              3121 non-null   object
#  8   year               3121 non-null   int64
#  9   released           3120 non-null   object
#  10  score              3121 non-null   float64
#  11  votes              3121 non-null   float64
#  12  director           3121 non-null   object
#  13  writer             3121 non-null   object
#  14  star               3121 non-null   object
#  15  country            3120 non-null   object
#  16  budget             3004 non-null   float64
#  17  gross              3114 non-null   float64
#  18  company            3120 non-null   object
#  19  runtime            3119 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(10)
# memory usage: 512.0+ KB

# %%
# Check for duplicates in the dataset Merged_Movie_df
print(f"Duplicate entries: {Merged_Movie_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
Merged_Movie_df.nunique()
# Out:
# Release Date         1862
# Movie Title          2923
# Production Budget     244
# Domestic Gross       2959
# Worldwide Gross      2961
# name                 2923
# rating                  8
# genre                  14
# year                   41
# released             1732
# score                  69
# votes                 633
# director             1287
# writer               1933
# star                 1031
# country                36
# budget                241
# gross                3033
# company               735
# runtime               124
# dtype: int64

# %%
Merged_Movie_df.columns
# Out:
# Index(['Release Date', 'Movie Title', 'Production Budget', 'Domestic Gross',
#        'Worldwide Gross', 'name', 'rating', 'genre', 'year', 'released',
#        'score', 'votes', 'director', 'writer', 'star', 'country', 'budget',
#        'gross', 'company', 'runtime'],
#       dtype='object')

# %%
Merged_Movie_df.rename(columns={'Release Date':'Release_Date', 'Movie Title':'Movie_Title', 'Production Budget':'Production_Budget', 'Domestic Gross':'Domestic_Gross',
       'Worldwide Gross':'Worldwide_Gross'},inplace=True)

# %%
Merged_Movie_df.head()
# Out:
#   Release_Date              Movie_Title  ...         company  runtime
# 0   2019-04-23        Avengers: Endgame  ...  Marvel Studios    181.0
# 1   2015-04-22  Avengers: Age of Ultron  ...  Marvel Studios    141.0
# 2   2018-04-25   Avengers: Infinity War  ...  Marvel Studios    149.0
# 3   2017-11-13           Justice League  ...    Warner Bros.    120.0
# 4   2015-06-10                  Spectre  ...             B24    148.0
#
# [5 rows x 20 columns]

# %%
# Check IMDB score column to categorize the score ratings as Favorable vs Unfavorable
Merged_Movie_df.score.unique()
# Out:
# array([8.4, 7.3, 6.1, 6.8, 6.9, 6.6, 6.4, 8.5, 7.7, 6.2, 7.8, 7.6, 7.4,
#        6. , 6.5, 3.8, 8. , 7. , 5.8, 5.2, 5.6, 5.3, 7.2, 8.2, 7.1, 6.3,
#        7.9, 5.5, 5.4, 6.7, 9. , 7.5, 8.1, 5.9, 4.9, 8.6, 8.8, 5.7, 4. ,
#        5.1, 5. , 4.8, 4.6, 3.9, 4.2, 8.3, 3.4, 2.2, 4.5, 8.9, 8.7, 4.3,
#        3.3, 4.7, 3.1, 3.7, 4.4, 2.5, 2.7, 4.1, 2.8, 3.5, 9.3, 2.9, 2.4,
#        1.9, 3.2, 3.6, 2.1])

# %%
# Transform the score into over 5 or under 5 categories

def change_score_to_Category(IMDB):
  if IMDB >= 6 :
    return "Favorable"
  else: 
    return "Unfavorable"

Merged_Movie_df['score'] = Merged_Movie_df['score'].apply(change_score_to_Category)
Merged_Movie_df.head()
# Out:
#   Release_Date              Movie_Title  ...         company  runtime
# 0   2019-04-23        Avengers: Endgame  ...  Marvel Studios    181.0
# 1   2015-04-22  Avengers: Age of Ultron  ...  Marvel Studios    141.0
# 2   2018-04-25   Avengers: Infinity War  ...  Marvel Studios    149.0
# 3   2017-11-13           Justice League  ...    Warner Bros.    120.0
# 4   2015-06-10                  Spectre  ...             B24    148.0
#
# [5 rows x 20 columns]

# %%
# Create Custom Encoding for IMDB Score


# score_to_Category = {
#  "Favorable": 1,
#  "Unfavorable": 0,

#}

# %%
# Create Custom Encoding for IMDB Score
#Merged_Movie_df["score_to_Category"] = Merged_Movie_df["score"].apply(lambda x: score_to_Category[x])

# %%
#from google.colab import files
#Merged_Movie_df.to_csv('Merged_Movie_New.csv') 
#files.download('Merged_Movie_New.csv')

# %%
Merged_Movie_df.nunique()
# Out:
# Release_Date         1862
# Movie_Title          2923
# Production_Budget     244
# Domestic_Gross       2959
# Worldwide_Gross      2961
# name                 2923
# rating                  8
# genre                  14
# year                   41
# released             1732
# score                   2
# votes                 633
# director             1287
# writer               1933
# star                 1031
# country                36
# budget                241
# gross                3033
# company               735
# runtime               124
# dtype: int64

# %%
Merged_Movie_df.dtypes
# Out:
# Release_Date         datetime64[ns]
# Movie_Title                  object
# Production_Budget             int64
# Domestic_Gross                int64
# Worldwide_Gross               int64
# name                         object
# rating                       object
# genre                        object
# year                          int64
# released                     object
# score                        object
# votes                       float64
# director                     object
# writer                       object
# star                         object
# country                      object
# budget                      float64
# gross                       float64
# company                      object
# runtime                     float64
# dtype: object

# %%
# Check for null values
for column in Merged_Movie_df.columns:
    print(f"Column {column} has {Merged_Movie_df[column].isnull().sum()} null values")
# Out:
# Column Release_Date has 0 null values
# Column Movie_Title has 0 null values
# Column Production_Budget has 0 null values
# Column Domestic_Gross has 0 null values
# Column Worldwide_Gross has 0 null values
# Column name has 0 null values
# Column rating has 4 null values
# Column genre has 0 null values
# Column year has 0 null values
# Column released has 1 null values
# Column score has 0 null values
# Column votes has 0 null values
# Column director has 0 null values
# Column writer has 0 null values
# Column star has 0 null values
# Column country has 1 null values
# Column budget has 117 null values
# Column gross has 7 null values
# Column company has 1 null values
# Column runtime has 2 null values

# %%
Merged_Movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3121 entries, 0 to 3120
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       3121 non-null   datetime64[ns]
#  1   Movie_Title        3121 non-null   object
#  2   Production_Budget  3121 non-null   int64
#  3   Domestic_Gross     3121 non-null   int64
#  4   Worldwide_Gross    3121 non-null   int64
#  5   name               3121 non-null   object
#  6   rating             3117 non-null   object
#  7   genre              3121 non-null   object
#  8   year               3121 non-null   int64
#  9   released           3120 non-null   object
#  10  score              3121 non-null   object
#  11  votes              3121 non-null   float64
#  12  director           3121 non-null   object
#  13  writer             3121 non-null   object
#  14  star               3121 non-null   object
#  15  country            3120 non-null   object
#  16  budget             3004 non-null   float64
#  17  gross              3114 non-null   float64
#  18  company            3120 non-null   object
#  19  runtime            3119 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(11)
# memory usage: 512.0+ KB

# %%
# Drop Null Rows and useless columns

Merged_Movie_df = Merged_Movie_df.dropna()
# Remove two columns name is 'name' and 'released' and Release_Date and 'country'
Merged_Movie_df = Merged_Movie_df.drop(['name', 'released', 'Release_Date', 'country' ], axis = 1)

# %%
Merged_Movie_df = Merged_Movie_df.drop_duplicates(subset= 'Movie_Title', keep= 'first', inplace=False)

# %%
Merged_Movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2847 entries, 0 to 3120
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Movie_Title        2847 non-null   object
#  1   Production_Budget  2847 non-null   int64
#  2   Domestic_Gross     2847 non-null   int64
#  3   Worldwide_Gross    2847 non-null   int64
#  4   rating             2847 non-null   object
#  5   genre              2847 non-null   object
#  6   year               2847 non-null   int64
#  7   score              2847 non-null   object
#  8   votes              2847 non-null   float64
#  9   director           2847 non-null   object
#  10  writer             2847 non-null   object
#  11  star               2847 non-null   object
#  12  budget             2847 non-null   float64
#  13  gross              2847 non-null   float64
#  14  company            2847 non-null   object
#  15  runtime            2847 non-null   float64
# dtypes: float64(4), int64(4), object(8)
# memory usage: 378.1+ KB

# %%
# Check for null values
for column in Merged_Movie_df.columns:
    print(f"Column {column} has {Merged_Movie_df[column].isnull().sum()} null values")
# Out:
# Column Movie_Title has 0 null values
# Column Production_Budget has 0 null values
# Column Domestic_Gross has 0 null values
# Column Worldwide_Gross has 0 null values
# Column rating has 0 null values
# Column genre has 0 null values
# Column year has 0 null values
# Column score has 0 null values
# Column votes has 0 null values
# Column director has 0 null values
# Column writer has 0 null values
# Column star has 0 null values
# Column budget has 0 null values
# Column gross has 0 null values
# Column company has 0 null values
# Column runtime has 0 null values

# %%
Merged_Movie_df.columns
# Out:
# Index(['Movie_Title', 'Production_Budget', 'Domestic_Gross', 'Worldwide_Gross',
#        'rating', 'genre', 'year', 'score', 'votes', 'director', 'writer',
#        'star', 'budget', 'gross', 'company', 'runtime'],
#       dtype='object')

# %%
# Transform Production_Budget column to scale for the model
Merged_Movie_df['Production_Budget'] =  Merged_Movie_df['Production_Budget']/1000000
# Transform Domestic_Gross column to scale for the model
Merged_Movie_df['Domestic_Gross'] = Merged_Movie_df['Domestic_Gross']/1000000
# Transform Worldwide_Gross column to scale for the model
Merged_Movie_df['Worldwide_Gross'] = Merged_Movie_df['Worldwide_Gross']/1000000
# Transform budget column to scale for the model
Merged_Movie_df['budget'] = Merged_Movie_df['budget']/1000000
# Transform gross column to scale for the model
Merged_Movie_df['gross'] = Merged_Movie_df['gross']/1000000
# Transform votes column to scale for the model
Merged_Movie_df['votes'] = Merged_Movie_df['votes']/10000


Merged_Movie_df.head()
# Out:
#                Movie_Title  Production_Budget  ...         company  runtime
# 0        Avengers: Endgame              400.0  ...  Marvel Studios    181.0
# 1  Avengers: Age of Ultron              365.0  ...  Marvel Studios    141.0
# 2   Avengers: Infinity War              300.0  ...  Marvel Studios    149.0
# 3           Justice League              300.0  ...    Warner Bros.    120.0
# 4                  Spectre              300.0  ...             B24    148.0
#
# [5 rows x 16 columns]

# %%
# Select all of the columns with a object dtype
Merged_Movie_df.select_dtypes(include = 'object')
# Out:
#                   Movie_Title  ...                    company
# 0           Avengers: Endgame  ...             Marvel Studios
# 1     Avengers: Age of Ultron  ...             Marvel Studios
# 2      Avengers: Infinity War  ...             Marvel Studios
# 3              Justice League  ...               Warner Bros.
# 4                     Spectre  ...                        B24
# ...                       ...  ...                        ...
# 3115            The Lost City  ...    Crescent Drive Pictures
# 3116              Next Friday  ...            New Line Cinema
# 3117          Poltergeist III  ...  Metro-Goldwyn-Mayer (MGM)
# 3119             The Runaways  ...   River Road Entertainment
# 3120        Gentlemen Broncos  ...         Bronco Productions
#
# [2997 rows x 8 columns]

# %%
# Hot encoding categorical columns
# Merged_Movie_encoded = pd.get_dummies(Merged_Movie_df, columns=[ "Movie_Title","rating","genre","director","writer","star","country","company"])
# Merged_Movie_encoded.head()
# Out:
#    Production_Budget  ...  company_double A Films
# 0              400.0  ...                       0
# 1              365.0  ...                       0
# 2              300.0  ...                       0
# 3              300.0  ...                       0
# 4              300.0  ...                       0
#
# [5 rows x 7650 columns]

# %%
# X = Merged_Movie_encoded.copy()
# X.head()
# Out:
#    Production_Budget  ...  company_double A Films
# 0              400.0  ...                       0
# 1              365.0  ...                       0
# 2              300.0  ...                       0
# 3              300.0  ...                       0
# 4              300.0  ...                       0
#
# [5 rows x 7650 columns]

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Movie_Title', 'rating', 'genre', 'score','director','writer','star','company']

# %%
df2 = Merged_Movie_df.copy()

# %%
df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)

# %%
# Hot incode method using label encoder

# le = LabelEncoder()
#df2 = Merged_Movie_df.copy()
#df2["Movie_Title"] = le.fit_transform(df2["Movie_Title"]) 
#df2["rating"] = le.fit_transform(df2["rating"]) 
#df2["genre"] = le.fit_transform(df2["genre"]) 
#df2["score"] = le.fit_transform(df2["score"]) 
#df2["director"] = le.fit_transform(df2["director"]) 
#df2["writer"] = le.fit_transform(df2["writer"]) 
#df2["star"] = le.fit_transform(df2["star"]) 
#df2["company"] = le.fit_transform(df2["company"]) 
#df2.head()
# Out:
#    Movie_Title  Production_Budget  ...  company  runtime
# 0          213              400.0  ...      455    181.0
# 1          212              365.0  ...      455    141.0
# 2          214              300.0  ...      455    149.0
# 3         1128              300.0  ...      658    120.0
# 4         1865              300.0  ...       86    148.0
#
# [5 rows x 16 columns]

# %%
df2.head()
# Out:
#    Movie_Title  Production_Budget  ...  company  runtime
# 0          213              400.0  ...      455    181.0
# 1          212              365.0  ...      455    141.0
# 2          214              300.0  ...      455    149.0
# 3         1128              300.0  ...      658    120.0
# 4         1865              300.0  ...       86    148.0
#
# [5 rows x 16 columns]

# %%
# Define features set

# X = X.drop("score_to_Category", axis=1)
# X.head()
# Out:
#    Production_Budget  ...  company_double A Films
# 0              400.0  ...                       0
# 1              365.0  ...                       0
# 2              300.0  ...                       0
# 3              300.0  ...                       0
# 4              300.0  ...                       0
#
# [5 rows x 7649 columns]

# %%
# Using list comprehension we can drop not useful columns.
# X = Merged_Movie_df.copy()
# x_cols = [i for i in Merged_Movie_df.columns if i not in ("score", "released")]
# X = Merged_Movie_df[x_cols]
# X.head()

# %%
X =df2
X = X.drop("score", axis=1)
X.head()
# Out:
#    Movie_Title  Production_Budget  ...  company  runtime
# 0          213              400.0  ...      455    181.0
# 1          212              365.0  ...      455    141.0
# 2          214              300.0  ...      455    149.0
# 3         1128              300.0  ...      658    120.0
# 4         1865              300.0  ...       86    148.0
#
# [5 rows x 15 columns]

# %%
X.describe()
# Out:
#        Movie_Title  Production_Budget  ...      company      runtime
# count  2997.000000        2997.000000  ...  2997.000000  2997.000000
# mean   1423.424758          51.270499  ...   436.050050   111.229897
# std     818.420472          46.767550  ...   191.682992    19.268937
# min       0.000000           9.500000  ...     0.000000    63.000000
# 25%     721.000000          20.000000  ...   258.000000    98.000000
# 50%    1427.000000          35.000000  ...   486.000000   108.000000
# 75%    2132.000000          65.000000  ...   629.000000   122.000000
# max    2846.000000         400.000000  ...   676.000000   271.000000
#
# [8 rows x 15 columns]

# %%
# Define target vector
y = df2["score"]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: score, dtype: int64

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 0    2163
# 1     834
# Name: score, dtype: int64

# %%
# Splitting into Train and Test sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# **Fit the Decision Tree Model**

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Random forest
#
# * Statistical algorithm that is used to cluster points of data in functional groups.
# * The random forest algorithm is a supervised learning model; it uses labeled data to “learn” how to classify unlabeled data.

# %% [markdown]
# **Random forest algorithms are beneficial because they:**
#
# *   Are robust against overfitting as all of those weak learners are trained on different pieces of the data.
# *  Can be used to rank the importance of input variables in a natural way.
# *   Can handle thousands of input variables without variable deletion.
# *   Are robust to outliers and nonlinear data.
# *   Run efficiently on large datasets.

# %% [markdown]
# The n_estimators will allow us to set the number of trees that will be created by the algorithm. Generally, the higher number makes the predictions stronger and more stable, but can slow down the output because of the higher training time allocated. The best practice is to use between 64 and 128 random forests, though higher numbers are quite common despite the higher training time.

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# %% [markdown]
# # **Fit the Decision Tree Model**

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %% [markdown]
# # **Make Predictions Using the Testing Data**

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# # **Evaluate the Model**

# %%
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          520           32
# Actual 1           95          103

# %% [markdown]
# # **Summary of Performancd: Confusion Matrix**

# %% [markdown]
# *   Out of 552 movies that obtained a "Favorable IMDB Score" (Actual 0), 520 were predicted to have a "Favorable IMDB Score" (Predicted 0), which is known as true positives.
#
# *   Out of 552 movies that obtained a "Favorable IMDB Score" (Actual 0), 32 were predicted to have a "Unfavorable IMDB Score" (Predicted 1), which are considered false negatives.
#
# *   Out of 198 movies that obtained a "Unfavorable IMDB Score" (Actual 1), 95 were predicted to have a "Favorable IMDB Score" (Predicted 0) and are considered false positives.
#
# *   Out of 198 movies that obtained a "Unfavorable IMDB Score" (Actual 1), 103
#  were predicted to be have a "Unfavorable IMDB Score" (Predicted 1) and are considered true negatives.

# %% [markdown]
# # **Below you can see that the model obtains a 83% Accuracy which is how often the classifier is correct!**

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.8306666666666667

# %% [markdown]
# # The accuracy of our model is 0.831, which can also be calculated as follows:
# **(True Positives (TP) + True Negatives (TN)) / Total = (520 + 103)/750 = 0.831**

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          520           32
# Actual 1           95          103
# Accuracy Score : 0.8306666666666667
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89       552
#            1       0.76      0.52      0.62       198
#
#     accuracy                           0.83       750
#    macro avg       0.80      0.73      0.75       750
# weighted avg       0.82      0.83      0.82       750

# %% [markdown]
# Precision: Precision is the measure of how reliable a positive classification is. From our results, the precision for the good IMDB movie scores can be determined by the ratio TP/(TP + FP), which is 520/(520 + 95) = 0.85. The precision for the bad loan applications can be determined as follows: 103/(103 + 32) = 0.763. A low precision is indicative of a large number of false positives—of the 135 movie IMDB scores we predicted to obtain bad scores, 32 were actually recieved good IMDB movie scores.

# %% [markdown]
# Recall: Recall is the ability of the classifier to find all the positive samples. It can be determined by the ratio: TP/(TP + FN), or 520/(520 + 32) = 0.942 for the good loans and 103/(103 + 95) = 0.520 for the bad IMDB movie scores. A low recall is indicative of a large number of false negatives.

# %% [markdown]
# F1 score: F1 score is a weighted average of the true positive rate (recall) and precision, where the best score is 1.0 and the worst is 0.0.

# %% [markdown]
# Support: Support is the number of actual occurrences of the class in the specified dataset. For our results, there are 552 actual occurrences for the good IMDB movie scores and 198 actual occurrences for bad IMDB movie scores.

# %%
# Calculate feature importance in the Random Forest model.
importances = rf_model.feature_importances_
importances
# Out:
# array([0.05637304, 0.05129851, 0.06763163, 0.06217728, 0.01882924,
#        0.03794966, 0.05119011, 0.19004147, 0.0535974 , 0.04925566,
#        0.05233783, 0.05051668, 0.06643716, 0.04732257, 0.14504177])

# %%
# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.19004146531878238, 'votes'),
#  (0.14504176929751458, 'runtime'),
#  (0.067631634771992, 'Domestic_Gross'),
#  (0.06643715845396098, 'gross'),
#  (0.062177281525161505, 'Worldwide_Gross'),
#  (0.05637303709167937, 'Movie_Title'),
#  (0.05359740012949985, 'director'),
#  (0.05233783066846515, 'star'),
#  (0.05129850853827459, 'Production_Budget'),
#  (0.05119010737753863, 'year'),
#  (0.05051667655747315, 'budget'),
#  (0.0492556607724103, 'writer'),
#  (0.04732256840187235, 'company'),
#  (0.037949658321521425, 'genre'),
#  (0.018829242773853696, 'rating')]

# %%
X.columns
# Out:
# Index(['Movie_Title', 'Production_Budget', 'Domestic_Gross', 'Worldwide_Gross',
#        'rating', 'genre', 'year', 'votes', 'director', 'writer', 'star',
#        'budget', 'gross', 'company', 'runtime'],
#       dtype='object')

# %% [markdown]
# # **Display Feature Importance using a Bar Graph Below**

# %%
from sklearn.ensemble import RandomForestClassifier
from yellowbrick.model_selection import FeatureImportances


model = RandomForestClassifier(n_estimators=15)
viz = FeatureImportances(model)
viz.fit(X, y)
viz.show()

# %% [markdown]
# # **Ensemble Learners**

# %% [markdown]
# # Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
BlRFC = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
BlRFC.fit(X_train, y_train)  
y_pred = BlRFC.predict(X_test)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8114569609134827

# %%
# Display the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index = ['Actual favorable IMDB Score', 'Actual Unfavorable IMDB Score'], columns=['Predicted favorable IMDB Score', 'Predicted Unfavorable IMDB Score'])
cm_df
# Out:
#                                Predicted favorable IMDB Score  Predicted Unfavorable IMDB Score
# Actual favorable IMDB Score                               447                               105
# Actual Unfavorable IMDB Score                              37                               161

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.81      0.81      0.86      0.81      0.66       552
#           1       0.61      0.81      0.81      0.69      0.81      0.66       198
#
# avg / total       0.84      0.81      0.81      0.82      0.81      0.66       750

# %%
# List the features sorted in descending order by feature importance
sorted(zip(BlRFC.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.19957491290355261, 'votes'),
#  (0.14647322943469418, 'runtime'),
#  (0.06867127708631279, 'Worldwide_Gross'),
#  (0.06696901683090392, 'Domestic_Gross'),
#  (0.06654424784291614, 'gross'),
#  (0.055683931193920115, 'Movie_Title'),
#  (0.05394083280389622, 'star'),
#  (0.0518409197517334, 'Production_Budget'),
#  (0.05103861727858889, 'budget'),
#  (0.04864216050417413, 'writer'),
#  (0.04853631740994779, 'year'),
#  (0.04688596145965551, 'director'),
#  (0.04446878455020804, 'company'),
#  (0.03328656925276334, 'genre'),
#  (0.017443221696732857, 'rating')]

# %% [markdown]
# # **Easy Ensemble AdaBoost Classifier**

# %%
# !pip install scikit-learn==1.0 -U
# Out:
# Requirement already satisfied: scikit-learn==1.0 in /usr/local/lib/python3.7/dist-packages (1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==1.0) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==1.0) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==1.0) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==1.0) (1.19.5)

# %%
# Train the EasyEnsembleClassifier

from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
# Fit the model
eec = eec.fit(X_train, y_train) 
# Make Prediction
y_pred = eec.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-323-11d4b1907ef7> in <module>()
#       4 eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
#       5 # Fit the model
# ----> 6 eec = eec.fit(X_train, y_train)
#       7 # Make Prediction
#       8 y_pred = eec.predict(X_test)
#
# /usr/local/lib/python3.7/dist-packages/imblearn/ensemble/_easy_ensemble.py in fit(self, X, y)
#     222         # RandomUnderSampler is not supporting sample_weight. We need to pass
#     223         # None.
# --> 224         return self._fit(X, y, self.max_samples, sample_weight=None)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     335             max_features = self.max_features
#     336         elif isinstance(self.max_features, float):
# --> 337             max_features = self.max_features * self.n_features_in_
#     338         else:
#     339             raise ValueError("max_features must be int or float")
#
# AttributeError: 'EasyEnsembleClassifier' object has no attribute 'n_features_in_'

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.8000992063492063

# %%
# Display the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index = ['Actual favorable IMDB Score', 'Actual Unfavorable IMDB Score'], columns=['Predicted favorable IMDB Score', 'Predicted Unfavorable IMDB Score'])
cm_df
# Out:
#                                Predicted favorable IMDB Score  Predicted Unfavorable IMDB Score
# Actual favorable IMDB Score                               339                                93
# Actual Unfavorable IMDB Score                              31                               137

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.78      0.82      0.85      0.80      0.64       432
#           1       0.60      0.82      0.78      0.69      0.80      0.64       168
#
# avg / total       0.83      0.79      0.81      0.80      0.80      0.64       600

# %% [markdown]
# # **Neural Network**

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = 15
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 80)                1280
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,741
# Trainable params: 3,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
     save_freq='epoch',
    period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 71/71 [==============================] - 1s 2ms/step - loss: 0.5855 - accuracy: 0.6867
# Epoch 2/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4975 - accuracy: 0.7388
# Epoch 3/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4558 - accuracy: 0.7793
# Epoch 4/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.7895
# Epoch 5/200
# 50/71 [====================>.........] - ETA: 0s - loss: 0.4245 - accuracy: 0.7881
# Epoch 00005: saving model to checkpoints/weights.05.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4157 - accuracy: 0.7980
# Epoch 6/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8033
# Epoch 7/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8184
# Epoch 8/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8220
# Epoch 9/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8242
# Epoch 10/200
# 54/71 [=====================>........] - ETA: 0s - loss: 0.3679 - accuracy: 0.8247
# Epoch 00010: saving model to checkpoints/weights.10.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8251
# Epoch 11/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8251
# Epoch 12/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8353
# Epoch 13/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8376
# Epoch 14/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3456 - accuracy: 0.8460
# Epoch 15/200
# 69/71 [============================>.] - ETA: 0s - loss: 0.3414 - accuracy: 0.8401
# Epoch 00015: saving model to checkpoints/weights.15.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8398
# Epoch 16/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8522
# Epoch 17/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8433
# Epoch 18/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3278 - accuracy: 0.8500
# Epoch 19/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3245 - accuracy: 0.8589
# Epoch 20/200
# 49/71 [===================>..........] - ETA: 0s - loss: 0.3213 - accuracy: 0.8578
# Epoch 00020: saving model to checkpoints/weights.20.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.8594
# Epoch 21/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3168 - accuracy: 0.8652
# Epoch 22/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3142 - accuracy: 0.8620
# Epoch 23/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3088 - accuracy: 0.8629
# Epoch 24/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8620
# Epoch 25/200
# 59/71 [=======================>......] - ETA: 0s - loss: 0.3017 - accuracy: 0.8655
# Epoch 00025: saving model to checkpoints/weights.25.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.3030 - accuracy: 0.8634
# Epoch 26/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2989 - accuracy: 0.8718
# Epoch 27/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.8709
# Epoch 28/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2913 - accuracy: 0.8741
# Epoch 29/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8745
# Epoch 30/200
# 53/71 [=====================>........] - ETA: 0s - loss: 0.2808 - accuracy: 0.8815
# Epoch 00030: saving model to checkpoints/weights.30.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.8781
# Epoch 31/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.8745
# Epoch 32/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2772 - accuracy: 0.8776
# Epoch 33/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.8838
# Epoch 34/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.8874
# Epoch 35/200
# 51/71 [====================>.........] - ETA: 0s - loss: 0.2770 - accuracy: 0.8762
# Epoch 00035: saving model to checkpoints/weights.35.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2648 - accuracy: 0.8852
# Epoch 36/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.8923
# Epoch 37/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8874
# Epoch 38/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.8910
# Epoch 39/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.8905
# Epoch 40/200
# 57/71 [=======================>......] - ETA: 0s - loss: 0.2551 - accuracy: 0.8953
# Epoch 00040: saving model to checkpoints/weights.40.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.8932
# Epoch 41/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.8985
# Epoch 42/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.8990
# Epoch 43/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9039
# Epoch 44/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2375 - accuracy: 0.9070
# Epoch 45/200
# 61/71 [========================>.....] - ETA: 0s - loss: 0.2338 - accuracy: 0.9042
# Epoch 00045: saving model to checkpoints/weights.45.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9021
# Epoch 46/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9039
# Epoch 47/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2271 - accuracy: 0.9105
# Epoch 48/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9003
# Epoch 49/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.9110
# Epoch 50/200
# 48/71 [===================>..........] - ETA: 0s - loss: 0.2228 - accuracy: 0.9069
# Epoch 00050: saving model to checkpoints/weights.50.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9097
# Epoch 51/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9132
# Epoch 52/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 0.9101
# Epoch 53/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9123
# Epoch 54/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2095 - accuracy: 0.9154
# Epoch 55/200
# 58/71 [=======================>......] - ETA: 0s - loss: 0.2097 - accuracy: 0.9192
# Epoch 00055: saving model to checkpoints/weights.55.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2072 - accuracy: 0.9212
# Epoch 56/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.2029 - accuracy: 0.9243
# Epoch 57/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1982 - accuracy: 0.9230
# Epoch 58/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9252
# Epoch 59/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9275
# Epoch 60/200
# 48/71 [===================>..........] - ETA: 0s - loss: 0.1993 - accuracy: 0.9212
# Epoch 00060: saving model to checkpoints/weights.60.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9203
# Epoch 61/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9257
# Epoch 62/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1894 - accuracy: 0.9261
# Epoch 63/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1885 - accuracy: 0.9310
# Epoch 64/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.9319
# Epoch 65/200
# 53/71 [=====================>........] - ETA: 0s - loss: 0.1760 - accuracy: 0.9322
# Epoch 00065: saving model to checkpoints/weights.65.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1809 - accuracy: 0.9261
# Epoch 66/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1772 - accuracy: 0.9315
# Epoch 67/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9337
# Epoch 68/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9332
# Epoch 69/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9377
# Epoch 70/200
# 54/71 [=====================>........] - ETA: 0s - loss: 0.1582 - accuracy: 0.9444
# Epoch 00070: saving model to checkpoints/weights.70.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9417
# Epoch 71/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9421
# Epoch 72/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9421
# Epoch 73/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9399
# Epoch 74/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9439
# Epoch 75/200
# 55/71 [======================>.......] - ETA: 0s - loss: 0.1518 - accuracy: 0.9443
# Epoch 00075: saving model to checkpoints/weights.75.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1558 - accuracy: 0.9417
# Epoch 76/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9417
# Epoch 77/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9408
# Epoch 78/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1491 - accuracy: 0.9506
# Epoch 79/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.9502
# Epoch 80/200
# 56/71 [======================>.......] - ETA: 0s - loss: 0.1423 - accuracy: 0.9520
# Epoch 00080: saving model to checkpoints/weights.80.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9506
# Epoch 81/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1375 - accuracy: 0.9573
# Epoch 82/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1478 - accuracy: 0.9488
# Epoch 83/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1455 - accuracy: 0.9488
# Epoch 84/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9528
# Epoch 85/200
# 48/71 [===================>..........] - ETA: 0s - loss: 0.1255 - accuracy: 0.9609
# Epoch 00085: saving model to checkpoints/weights.85.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1373 - accuracy: 0.9524
# Epoch 86/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9528
# Epoch 87/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9559
# Epoch 88/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9613
# Epoch 89/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9604
# Epoch 90/200
# 66/71 [==========================>...] - ETA: 0s - loss: 0.1236 - accuracy: 0.9645
# Epoch 00090: saving model to checkpoints/weights.90.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9653
# Epoch 91/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9635
# Epoch 92/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9604
# Epoch 93/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9653
# Epoch 94/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9644
# Epoch 95/200
# 49/71 [===================>..........] - ETA: 0s - loss: 0.1112 - accuracy: 0.9688
# Epoch 00095: saving model to checkpoints/weights.95.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9684
# Epoch 96/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9599
# Epoch 97/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9635
# Epoch 98/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9626
# Epoch 99/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9666
# Epoch 100/200
# 69/71 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9710
# Epoch 00100: saving model to checkpoints/weights.100.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9711
# Epoch 101/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9693
# Epoch 102/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 0.9644
# Epoch 103/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9702
# Epoch 104/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9755
# Epoch 105/200
# 56/71 [======================>.......] - ETA: 0s - loss: 0.0947 - accuracy: 0.9743
# Epoch 00105: saving model to checkpoints/weights.105.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.9742
# Epoch 106/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9711
# Epoch 107/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9769
# Epoch 108/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.9706
# Epoch 109/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9769
# Epoch 110/200
# 52/71 [====================>.........] - ETA: 0s - loss: 0.0904 - accuracy: 0.9760
# Epoch 00110: saving model to checkpoints/weights.110.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9769
# Epoch 111/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9755
# Epoch 112/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9733
# Epoch 113/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9764
# Epoch 114/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9737
# Epoch 115/200
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0875 - accuracy: 0.9755
# Epoch 00115: saving model to checkpoints/weights.115.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0884 - accuracy: 0.9742
# Epoch 116/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9804
# Epoch 117/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9795
# Epoch 118/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9755
# Epoch 119/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0902 - accuracy: 0.9729
# Epoch 120/200
# 48/71 [===================>..........] - ETA: 0s - loss: 0.0726 - accuracy: 0.9857
# Epoch 00120: saving model to checkpoints/weights.120.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 0.9822
# Epoch 121/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9804
# Epoch 122/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9786
# Epoch 123/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9835
# Epoch 124/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9777
# Epoch 125/200
# 53/71 [=====================>........] - ETA: 0s - loss: 0.0639 - accuracy: 0.9870
# Epoch 00125: saving model to checkpoints/weights.125.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9849
# Epoch 126/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0717 - accuracy: 0.9835
# Epoch 127/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9831
# Epoch 128/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9800
# Epoch 129/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9826
# Epoch 130/200
# 47/71 [==================>...........] - ETA: 0s - loss: 0.0698 - accuracy: 0.9840
# Epoch 00130: saving model to checkpoints/weights.130.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9866
# Epoch 131/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9858
# Epoch 132/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9858
# Epoch 133/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9844
# Epoch 134/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9898
# Epoch 135/200
# 55/71 [======================>.......] - ETA: 0s - loss: 0.0567 - accuracy: 0.9909
# Epoch 00135: saving model to checkpoints/weights.135.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9902
# Epoch 136/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9844
# Epoch 137/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9898
# Epoch 138/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9818
# Epoch 139/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9880
# Epoch 140/200
# 71/71 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9898
# Epoch 00140: saving model to checkpoints/weights.140.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9898
# Epoch 141/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9884
# Epoch 142/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9871
# Epoch 143/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9858
# Epoch 144/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9898
# Epoch 145/200
# 52/71 [====================>.........] - ETA: 0s - loss: 0.0487 - accuracy: 0.9904
# Epoch 00145: saving model to checkpoints/weights.145.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9911
# Epoch 146/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9911
# Epoch 147/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9920
# Epoch 148/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9924
# Epoch 149/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9947
# Epoch 150/200
# 50/71 [====================>.........] - ETA: 0s - loss: 0.0469 - accuracy: 0.9912
# Epoch 00150: saving model to checkpoints/weights.150.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9902
# Epoch 151/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9889
# Epoch 152/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9853
# Epoch 153/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9862
# Epoch 154/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9915
# Epoch 155/200
# 67/71 [===========================>..] - ETA: 0s - loss: 0.0436 - accuracy: 0.9911
# Epoch 00155: saving model to checkpoints/weights.155.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9915
# Epoch 156/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9924
# Epoch 157/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9911
# Epoch 158/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9942
# Epoch 159/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9942
# Epoch 160/200
# 69/71 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9918
# Epoch 00160: saving model to checkpoints/weights.160.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9915
# Epoch 161/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9942
# Epoch 162/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9924
# Epoch 163/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 0.9884
# Epoch 164/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9955
# Epoch 165/200
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0409 - accuracy: 0.9908
# Epoch 00165: saving model to checkpoints/weights.165.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9907
# Epoch 166/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9933
# Epoch 167/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9947
# Epoch 168/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9947
# Epoch 169/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9960
# Epoch 170/200
# 71/71 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9955
# Epoch 00170: saving model to checkpoints/weights.170.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 0.9955
# Epoch 171/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9951
# Epoch 172/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9960
# Epoch 173/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9955
# Epoch 174/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9969
# Epoch 175/200
# 57/71 [=======================>......] - ETA: 0s - loss: 0.0291 - accuracy: 0.9967
# Epoch 00175: saving model to checkpoints/weights.175.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9924
# Epoch 176/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9964
# Epoch 177/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9955
# Epoch 178/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9955
# Epoch 179/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9978
# Epoch 180/200
# 70/71 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9955
# Epoch 00180: saving model to checkpoints/weights.180.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9955
# Epoch 181/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9907
# Epoch 182/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9777
# Epoch 183/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9938
# Epoch 184/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9982
# Epoch 185/200
# 46/71 [==================>...........] - ETA: 0s - loss: 0.0269 - accuracy: 0.9973
# Epoch 00185: saving model to checkpoints/weights.185.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9973
# Epoch 186/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9942
# Epoch 187/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9973
# Epoch 188/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9982
# Epoch 189/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9991
# Epoch 190/200
# 46/71 [==================>...........] - ETA: 0s - loss: 0.0212 - accuracy: 0.9966
# Epoch 00190: saving model to checkpoints/weights.190.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9964
# Epoch 191/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9982
# Epoch 192/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9996
# Epoch 193/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9996
# Epoch 194/200
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9991
# Epoch 195/200
# 52/71 [====================>.........] - ETA: 0s - loss: 0.0171 - accuracy: 0.9994
# Epoch 00195: saving model to checkpoints/weights.195.hdf5
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9996
# Epoch 196/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9991
# Epoch 197/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9996
# Epoch 198/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9996
# Epoch 199/200
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9987
# Epoch 200/200
# 70/71 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9987
# Epoch 00200: saving model to checkpoints/weights.200.hdf5
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 0.9987

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 24/24 - 0s - loss: 0.9753 - accuracy: 0.8027 - 142ms/epoch - 6ms/step
# Loss: 0.9753182530403137, Accuracy: 0.8026666641235352
